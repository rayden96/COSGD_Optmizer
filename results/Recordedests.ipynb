# %% [markdown]
# # Test comparing data clustered COSGD against Control SGD

# %% [markdown]
# Using a stopping condition: patience with 20 epochs - best loss must decrease by 0.0001 (max 500 epochs)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(2, 128)
        self.fc2 = nn.Linear(128, 256)
        self.fc3 = nn.Linear(256, 256)
        self.fc4 = nn.Linear(256, 256)
        self.fc5 = nn.Linear(256, 128)
        self.fc6 = nn.Linear(128, 3)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = torch.relu(self.fc4(x))
        x = torch.relu(self.fc5(x))
        x = self.fc6(x)
        return x

# %% [markdown]
# f1 = np.sin(x1) + np.cos(x2) + np.sin(x1)*np.cos(x2)
# f2 = np.cos(np.pi*x1) + np.sin(np.pi*x2)
# f3 = np.sqrt(x1**2 + x2**2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # control - no early stopping

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Mean MAE: 0.41848674889488047 +/- 0.016512537954214566
Mean MSE: 0.3141769296616577 +/- 0.022889324327366577

# %% [markdown]
# # COSGD - stopped at epoch 234

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Mean MAE: 0.14947793202382428 +/- 0.005501979511197194
Mean MSE: 0.033729868830976194 +/- 0.0017078301583877218

# %% [markdown]
# # New Test

# %%
f1 = np.sin(2*np.pi*x1) + np.cos(2*np.pi*x2)
    f2 = np.cos(2*np.pi*x1) + np.sin(2*np.pi*x2)
    f3 = np.cos(2*np.pi*x1) + np.tanh(2*np.pi*x2)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(2, 128)
        self.fc2 = nn.Linear(128, 256)
        self.fc3 = nn.Linear(256, 512)
        self.fc4 = nn.Linear(512, 256)
        self.fc5 = nn.Linear(256, 128)
        self.fc6 = nn.Linear(128, 3)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = torch.relu(self.fc4(x))
        x = torch.relu(self.fc5(x))
        x = self.fc6(x)
        return x

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # control - no ealry stopping

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Mean MAE: 0.7905163574496836 +/- 0.026683413506363118
Mean MSE: 0.9334966417876578 +/- 0.0689721975915296

# %% [markdown]
# # COSGD - no ealry stopping

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Mean MAE: 0.3519074670147289 +/- 0.015156121320316454
Mean MSE: 0.18936431392167058 +/- 0.015840151763320463

# %% [markdown]
# # new test
